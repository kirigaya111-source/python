# %%
n = [0, 1, 2, 3, 4, 5]
tong_chan = 0
tong_le = 0
for x in n:
    if x % 2 == 0:
        tong_chan = tong_chan + x
    else:
        tong_le = tong_le + x
print(n)
print(tong_chan)
print(tong_le)
# Out:
# [0, 1, 2, 3, 4, 5]
# 6
# 9
